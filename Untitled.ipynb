# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Matches=pd.read_csv("C:\\Users\\saide\\Desktop\\Capstone Project\\ipldata\\matches.csv")

# %%
Matches.head()
# Out:
#    id  season        city       date                  team1  \
# 0   1    2008   Bangalore  4/18/2008  Kolkata Knight Riders
# 1   2    2008  Chandigarh  4/19/2008    Chennai Super Kings
# 2   3    2008       Delhi  4/19/2008       Rajasthan Royals
# 3   4    2008      Mumbai  4/20/2008         Mumbai Indians
# 4   5    2008     Kolkata  4/20/2008        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# 1  normal           0          Chennai Super Kings           33
# 2  normal           0             Delhi Daredevils            0
# 3  normal           0  Royal Challengers Bangalore            0
# 4  normal           0        Kolkata Knight Riders            0
#
#    win_by_wickets player_of_match                                       venue  \
# 0               0     BB McCullum                       M Chinnaswamy Stadium
# 1               0      MEK Hussey  Punjab Cricket Association Stadium, Mohali
# 2               9     MF Maharoof                            Feroz Shah Kotla
# 3               5      MV Boucher                            Wankhede Stadium
# 4               5       DJ Hussey                                Eden Gardens
#
#      umpire1         umpire2  umpire3
# 0  Asad Rauf     RE Koertzen      NaN
# 1  MR Benson      SL Shastri      NaN
# 2  Aleem Dar  GA Pratapkumar      NaN
# 3   SJ Davis       DJ Harper      NaN
# 4  BF Bowden     K Hariharan      NaN

# %%
Matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 18 columns):
# id                 577 non-null int64
# season             577 non-null int64
# city               570 non-null object
# date               577 non-null object
# team1              577 non-null object
# team2              577 non-null object
# toss_winner        577 non-null object
# toss_decision      577 non-null object
# result             577 non-null object
# dl_applied         577 non-null int64
# winner             574 non-null object
# win_by_runs        577 non-null int64
# win_by_wickets     577 non-null int64
# player_of_match    574 non-null object
# venue              577 non-null object
# umpire1            577 non-null object
# umpire2            577 non-null object
# umpire3            0 non-null float64
# dtypes: float64(1), int64(5), object(12)
# memory usage: 81.2+ KB

# %% [raw]
#  Conver String type variable to Float.

# %%
Matches.replace(['Deccan Chargers','Delhi Daredevils','Pune Warriors','Rising Pune Supergiants'],['Sunrisers Hyderabad','Delhi Captials','Rising Pune Supergiant','Rising Pune Supergiant'],inplace=True)

encode = {'team1': {'Mumbai Indians':1,'Kolkata Knight Riders':2,'Royal Challengers Bangalore':3,'Delhi Captials':4,'Chennai Super Kings':5,'Rajasthan Royals':6,'Gujarat Lions':7,'Kings XI Punjab':8,'Sunrisers Hyderabad':9,'Rising Pune Supergiant':10,'Kochi Tuskers Kerala':11,},
          'team2': {'Mumbai Indians':1,'Kolkata Knight Riders':2,'Royal Challengers Bangalore':3,'Delhi Captials':4,'Chennai Super Kings':5,'Rajasthan Royals':6,'Gujarat Lions':7,'Kings XI Punjab':8,'Sunrisers Hyderabad':9,'Rising Pune Supergiant':10,'Kochi Tuskers Kerala':11,},
          'toss_winner': {'Mumbai Indians':1,'Kolkata Knight Riders':2,'Royal Challengers Bangalore':3,'Delhi Captials':4,'Chennai Super Kings':5,'Rajasthan Royals':6,'Gujarat Lions':7,'Kings XI Punjab':8,'Sunrisers Hyderabad':9,'Rising Pune Supergiant':10,'Kochi Tuskers Kerala':11,},
          'winner': {'Mumbai Indians':1,'Kolkata Knight Riders':2,'Royal Challengers Bangalore':3,'Delhi Captials':4,'Chennai Super Kings':5,'Rajasthan Royals':6,'Gujarat Lions':7,'Kings XI Punjab':8,'Sunrisers Hyderabad':9,'Rising Pune Supergiant':10,'Kochi Tuskers Kerala':11,'Draw':12}}
Matches.replace(encode, inplace=True)
Matches.head(100)
# Out:
#      id  season            city       date  team1  team2  toss_winner  \
# 0     1    2008       Bangalore  4/18/2008      2      3            3
# 1     2    2008      Chandigarh  4/19/2008      5      8            5
# 2     3    2008           Delhi  4/19/2008      6      4            6
# 3     4    2008          Mumbai  4/20/2008      1      3            1
# 4     5    2008         Kolkata  4/20/2008      9      2            9
# 5     6    2008          Jaipur  4/21/2008      8      6            8
# 6     7    2008       Hyderabad  4/22/2008      9      4            9
# 7     8    2008         Chennai  4/23/2008      5      1            1
# 8     9    2008       Hyderabad  4/24/2008      9      6            6
# 9    10    2008      Chandigarh  4/25/2008      8      1            1
# 10   11    2008       Bangalore  4/26/2008      3      6            6
# 11   12    2008         Chennai  4/26/2008      2      5            2
# 12   13    2008          Mumbai  4/27/2008      1      9            9
# 13   14    2008      Chandigarh  4/27/2008      4      8            4
# 14   15    2008       Bangalore  4/28/2008      5      3            5
# 15   16    2008         Kolkata  4/29/2008      2      1            2
# 16   17    2008           Delhi  4/30/2008      4      3            3
# 17   18    2008       Hyderabad   5/1/2008      9      8            8
# 18   19    2008          Jaipur   5/1/2008      6      2            6
# 19   20    2008         Chennai   5/2/2008      5      4            5
# 20   21    2008       Hyderabad  5/25/2008      9      3            9
# 21   22    2008      Chandigarh   5/3/2008      8      2            8
# 22   23    2008          Mumbai   5/4/2008      1      4            4
# 23   24    2008          Jaipur   5/4/2008      5      6            5
# 24   25    2008       Bangalore   5/5/2008      3      8            8
# 25   26    2008         Chennai   5/6/2008      5      9            9
# 26   27    2008          Mumbai   5/7/2008      6      1            1
# 27   28    2008           Delhi   5/8/2008      4      5            5
# 28   29    2008         Kolkata   5/8/2008      2      3            2
# 29   30    2008          Jaipur   5/9/2008      9      6            6
# ..  ...     ...             ...        ...    ...    ...          ...
# 70   71    2009       Cape Town  4/26/2009      8      6            8
# 71   72    2009          Durban  4/27/2009      5      9            9
# 72   73    2009  Port Elizabeth  4/27/2009      1      2            1
# 73   74    2009       Centurion  4/28/2009      4      6            4
# 74   75    2009          Durban  4/29/2009      2      3            2
# 75   76    2009          Durban  4/29/2009      8      1            8
# 76   77    2009       Centurion  4/30/2009      9      4            4
# 77   78    2009       Centurion  4/30/2009      5      6            6
# 78   79    2009     East London   5/1/2009      1      2            1
# 79   80    2009          Durban   5/1/2009      3      8            3
# 80   81    2009  Port Elizabeth   5/2/2009      9      6            9
# 81   82    2009    Johannesburg   5/2/2009      5      4            4
# 82   83    2009  Port Elizabeth   5/3/2009      2      8            2
# 83   84    2009    Johannesburg   5/3/2009      1      3            1
# 84   85    2009     East London   5/4/2009      5      9            5
# 85   86    2009          Durban   5/5/2009      6      8            8
# 86   87    2009          Durban   5/5/2009      2      4            2
# 87   88    2009       Centurion   5/6/2009      9      1            9
# 88   89    2009       Centurion   5/7/2009      3      6            6
# 89   90    2009       Centurion   5/7/2009      5      8            5
# 90   91    2009     East London   5/8/2009      1      4            1
# 91   92    2009       Kimberley   5/9/2009      9      8            8
# 92   93    2009       Kimberley   5/9/2009      6      5            6
# 93   94    2009  Port Elizabeth  5/10/2009      1      3            1
# 94   95    2009    Johannesburg  5/10/2009      2      4            4
# 95   96    2009       Kimberley  5/11/2009      9      6            9
# 96   97    2009       Centurion  5/12/2009      2      3            3
# 97   98    2009       Centurion  5/12/2009      8      1            8
# 98   99    2009          Durban  5/13/2009      4      9            9
# 99  100    2009          Durban  5/14/2009      5      3            5
#
#    toss_decision  result  dl_applied  winner  win_by_runs  win_by_wickets  \
# 0          field  normal           0     2.0          140               0
# 1            bat  normal           0     5.0           33               0
# 2            bat  normal           0     4.0            0               9
# 3            bat  normal           0     3.0            0               5
# 4            bat  normal           0     2.0            0               5
# 5            bat  normal           0     6.0            0               6
# 6            bat  normal           0     4.0            0               9
# 7          field  normal           0     5.0            6               0
# 8          field  normal           0     6.0            0               3
# 9          field  normal           0     8.0           66               0
# 10         field  normal           0     6.0            0               7
# 11           bat  normal           0     5.0            0               9
# 12         field  normal           0     9.0            0              10
# 13           bat  normal           0     8.0            0               4
# 14           bat  normal           0     5.0           13               0
# 15           bat  normal           0     1.0            0               7
# 16         field  normal           0     4.0           10               0
# 17         field  normal           0     8.0            0               7
# 18           bat  normal           0     6.0           45               0
# 19           bat  normal           0     4.0            0               8
# 20           bat  normal           0     3.0            0               5
# 21           bat  normal           0     8.0            9               0
# 22         field  normal           0     1.0           29               0
# 23           bat  normal           0     6.0            0               8
# 24         field  normal           0     8.0            0               6
# 25         field  normal           0     9.0            0               7
# 26         field  normal           0     1.0            0               7
# 27         field  normal           0     5.0            0               4
# 28           bat  normal           0     2.0            5               0
# 29         field  normal           0     6.0            0               8
# ..           ...     ...         ...     ...          ...             ...
# 70           bat  normal           0     8.0           27               0
# 71         field  normal           0     9.0            0               6
# 72           bat  normal           0     1.0           92               0
# 73           bat  normal           0     6.0            0               5
# 74           bat  normal           0     3.0            0               5
# 75           bat  normal           0     8.0            3               0
# 76         field  normal           0     4.0            0               6
# 77         field  normal           0     5.0           38               0
# 78           bat  normal           0     1.0            9               0
# 79           bat  normal           0     3.0            8               0
# 80           bat  normal           0     6.0            0               3
# 81         field  normal           0     5.0           18               0
# 82           bat  normal           0     8.0            0               6
# 83           bat  normal           0     3.0            0               9
# 84           bat  normal           0     5.0           78               0
# 85         field  normal           0     6.0           78               0
# 86           bat  normal           0     4.0            0               9
# 87           bat  normal           0     9.0           19               0
# 88         field  normal           0     6.0            0               7
# 89           bat  normal           1     5.0           12               0
# 90           bat  normal           0     4.0            0               7
# 91         field  normal           0     8.0            0               3
# 92           bat  normal           0     5.0            0               7
# 93           bat  normal           0     1.0           16               0
# 94         field  normal           0     4.0            0               7
# 95           bat  normal           0     9.0           53               0
# 96         field  normal           0     3.0            0               6
# 97           bat  normal           0     1.0            0               8
# 98         field  normal           0     4.0           12               0
# 99           bat  normal           0     3.0            0               2
#
#      player_of_match                                       venue  \
# 0        BB McCullum                       M Chinnaswamy Stadium
# 1         MEK Hussey  Punjab Cricket Association Stadium, Mohali
# 2        MF Maharoof                            Feroz Shah Kotla
# 3         MV Boucher                            Wankhede Stadium
# 4          DJ Hussey                                Eden Gardens
# 5          SR Watson                      Sawai Mansingh Stadium
# 6           V Sehwag   Rajiv Gandhi International Stadium, Uppal
# 7          ML Hayden             MA Chidambaram Stadium, Chepauk
# 8          YK Pathan   Rajiv Gandhi International Stadium, Uppal
# 9      KC Sangakkara  Punjab Cricket Association Stadium, Mohali
# 10         SR Watson                       M Chinnaswamy Stadium
# 11          JDP Oram             MA Chidambaram Stadium, Chepauk
# 12      AC Gilchrist                  Dr DY Patil Sports Academy
# 13         SM Katich  Punjab Cricket Association Stadium, Mohali
# 14          MS Dhoni                       M Chinnaswamy Stadium
# 15     ST Jayasuriya                                Eden Gardens
# 16        GD McGrath                            Feroz Shah Kotla
# 17          SE Marsh   Rajiv Gandhi International Stadium, Uppal
# 18       SA Asnodkar                      Sawai Mansingh Stadium
# 19          V Sehwag             MA Chidambaram Stadium, Chepauk
# 20     R Vinay Kumar   Rajiv Gandhi International Stadium, Uppal
# 21         IK Pathan  Punjab Cricket Association Stadium, Mohali
# 22        SM Pollock                  Dr DY Patil Sports Academy
# 23     Sohail Tanvir                      Sawai Mansingh Stadium
# 24       S Sreesanth                       M Chinnaswamy Stadium
# 25      AC Gilchrist             MA Chidambaram Stadium, Chepauk
# 26           A Nehra                  Dr DY Patil Sports Academy
# 27          MS Dhoni                            Feroz Shah Kotla
# 28        SC Ganguly                                Eden Gardens
# 29         YK Pathan                      Sawai Mansingh Stadium
# ..               ...                                         ...
# 70     KC Sangakkara                                    Newlands
# 71          HH Gibbs                                   Kingsmead
# 72      SR Tendulkar                            St George's Park
# 73         YK Pathan                             SuperSport Park
# 74        MV Boucher                                   Kingsmead
# 75     KC Sangakkara                                   Kingsmead
# 76         DP Nannes                             SuperSport Park
# 77          SK Raina                             SuperSport Park
# 78         JP Duminy                                Buffalo Park
# 79      Yuvraj Singh                                   Kingsmead
# 80         YK Pathan                            St George's Park
# 81         SB Jakati                       New Wanderers Stadium
# 82  DPMD Jayawardene                            St George's Park
# 83         JH Kallis                       New Wanderers Stadium
# 84          MS Dhoni                                Buffalo Park
# 85          GC Smith                                   Kingsmead
# 86         G Gambhir                                   Kingsmead
# 87         RG Sharma                             SuperSport Park
# 88           A Singh                             SuperSport Park
# 89         ML Hayden                             SuperSport Park
# 90           A Nehra                                Buffalo Park
# 91  DPMD Jayawardene                       De Beers Diamond Oval
# 92       S Badrinath                       De Beers Diamond Oval
# 93         JP Duminy                            St George's Park
# 94          A Mishra                       New Wanderers Stadium
# 95          DR Smith                       De Beers Diamond Oval
# 96       LRPL Taylor                             SuperSport Park
# 97   Harbhajan Singh                             SuperSport Park
# 98          R Bhatia                                   Kingsmead
# 99       LRPL Taylor                                   Kingsmead
#
#             umpire1          umpire2  umpire3
# 0         Asad Rauf      RE Koertzen      NaN
# 1         MR Benson       SL Shastri      NaN
# 2         Aleem Dar   GA Pratapkumar      NaN
# 3          SJ Davis        DJ Harper      NaN
# 4         BF Bowden      K Hariharan      NaN
# 5         Aleem Dar        RB Tiffin      NaN
# 6         IL Howell        AM Saheba      NaN
# 7         DJ Harper   GA Pratapkumar      NaN
# 8         Asad Rauf        MR Benson      NaN
# 9         Aleem Dar        AM Saheba      NaN
# 10        MR Benson        IL Howell      NaN
# 11        BF Bowden   AV Jayaprakash      NaN
# 12        Asad Rauf       SL Shastri      NaN
# 13      RE Koertzen        I Shivram      NaN
# 14      BR Doctrove        RB Tiffin      NaN
# 15        BF Bowden   AV Jayaprakash      NaN
# 16        Aleem Dar        I Shivram      NaN
# 17      BR Doctrove        RB Tiffin      NaN
# 18      RE Koertzen   GA Pratapkumar      NaN
# 19        BF Bowden      K Hariharan      NaN
# 20        Asad Rauf      RE Koertzen      NaN
# 21        DJ Harper        I Shivram      NaN
# 22        IL Howell      RE Koertzen      NaN
# 23        Asad Rauf   AV Jayaprakash      NaN
# 24         SJ Davis      BR Doctrove      NaN
# 25        MR Benson        RB Tiffin      NaN
# 26        DJ Harper      RE Koertzen      NaN
# 27        Aleem Dar        RB Tiffin      NaN
# 28        Asad Rauf        IL Howell      NaN
# 29        MR Benson        AM Saheba      NaN
# ..              ...              ...      ...
# 70        M Erasmus      K Hariharan      NaN
# 71        IL Howell   TH Wijewardene      NaN
# 72       BG Jerling        RB Tiffin      NaN
# 73       GAV Baxter      RE Koertzen      NaN
# 74        MR Benson   TH Wijewardene      NaN
# 75        MR Benson       SL Shastri      NaN
# 76       GAV Baxter        AM Saheba      NaN
# 77       GAV Baxter      RE Koertzen      NaN
# 78        M Erasmus      SK Tarapore      NaN
# 79  HDPK Dharmasena           S Ravi      NaN
# 80         S Asnani       BG Jerling      NaN
# 81        DJ Harper      RE Koertzen      NaN
# 82         S Asnani        MR Benson      NaN
# 83      RE Koertzen   TH Wijewardene      NaN
# 84      BR Doctrove        M Erasmus      NaN
# 85        SS Hazare        IL Howell      NaN
# 86       GAV Baxter        IL Howell      NaN
# 87        MR Benson  HDPK Dharmasena      NaN
# 88      K Hariharan        DJ Harper      NaN
# 89        DJ Harper   TH Wijewardene      NaN
# 90        M Erasmus      SK Tarapore      NaN
# 91       GAV Baxter        AM Saheba      NaN
# 92       GAV Baxter  HDPK Dharmasena      NaN
# 93      BR Doctrove       BG Jerling      NaN
# 94       SL Shastri        RB Tiffin      NaN
# 95       GAV Baxter  HDPK Dharmasena      NaN
# 96        M Erasmus        SS Hazare      NaN
# 97        SS Hazare      RE Koertzen      NaN
# 98        DJ Harper       SL Shastri      NaN
# 99      BR Doctrove        DJ Harper      NaN
#
# [100 rows x 18 columns]

# %%
Matches.describe()
# Out:
#                id       season       team1       team2  toss_winner  \
# count  577.000000   577.000000  577.000000  577.000000   577.000000
# mean   289.000000  2012.029463    5.171577    5.031196     5.098787
# std    166.709828     2.486247    2.936839    2.861210     2.919454
# min      1.000000  2008.000000    1.000000    1.000000     1.000000
# 25%    145.000000  2010.000000    3.000000    3.000000     3.000000
# 50%    289.000000  2012.000000    5.000000    5.000000     5.000000
# 75%    433.000000  2014.000000    8.000000    8.000000     8.000000
# max    577.000000  2016.000000   11.000000   11.000000    11.000000
#
#        dl_applied      winner  win_by_runs  win_by_wickets  umpire3
# count  577.000000  574.000000   577.000000      577.000000      0.0
# mean     0.025997    4.865854    13.715771        3.363951      NaN
# std      0.159263    2.812547    23.619282        3.416049      NaN
# min      0.000000    1.000000     0.000000        0.000000      NaN
# 25%      0.000000    2.000000     0.000000        0.000000      NaN
# 50%      0.000000    5.000000     0.000000        3.000000      NaN
# 75%      0.000000    8.000000    20.000000        6.000000      NaN
# max      1.000000   11.000000   144.000000       10.000000      NaN

# %%
CorRelation=Matches.corr()
CorRelation
# Out:
#                       id    season     team1     team2  toss_winner  \
# id              1.000000  0.992806  0.040718  0.002719     0.001263
# season          0.992806  1.000000  0.047098  0.005484     0.002469
# team1           0.040718  0.047098  1.000000 -0.115925     0.426886
# team2           0.002719  0.005484 -0.115925  1.000000     0.464981
# toss_winner     0.001263  0.002469  0.426886  0.464981     1.000000
# dl_applied      0.017197  0.015600  0.034989  0.043936     0.065411
# winner          0.007155  0.011633  0.421323  0.435687     0.389022
# win_by_runs    -0.014813 -0.018098 -0.115627  0.068415    -0.013238
# win_by_wickets -0.012804 -0.005966  0.064716 -0.085535     0.036601
# umpire3              NaN       NaN       NaN       NaN          NaN
#
#                 dl_applied    winner  win_by_runs  win_by_wickets  umpire3
# id                0.017197  0.007155    -0.014813       -0.012804      NaN
# season            0.015600  0.011633    -0.018098       -0.005966      NaN
# team1             0.034989  0.421323    -0.115627        0.064716      NaN
# team2             0.043936  0.435687     0.068415       -0.085535      NaN
# toss_winner       0.065411  0.389022    -0.013238        0.036601      NaN
# dl_applied        1.000000  0.050568    -0.005878       -0.023803      NaN
# winner            0.050568  1.000000    -0.055477       -0.029174      NaN
# win_by_runs      -0.005878 -0.055477     1.000000       -0.572839      NaN
# win_by_wickets   -0.023803 -0.029174    -0.572839        1.000000      NaN
# umpire3                NaN       NaN          NaN             NaN      NaN

# %%
Matches.drop(['umpire3','umpire1','umpire2'],axis=1)
# Out:
#       id  season           city       date  team1  team2  toss_winner  \
# 0      1    2008      Bangalore  4/18/2008      2      3            3
# 1      2    2008     Chandigarh  4/19/2008      5      8            5
# 2      3    2008          Delhi  4/19/2008      6      4            6
# 3      4    2008         Mumbai  4/20/2008      1      3            1
# 4      5    2008        Kolkata  4/20/2008      9      2            9
# 5      6    2008         Jaipur  4/21/2008      8      6            8
# 6      7    2008      Hyderabad  4/22/2008      9      4            9
# 7      8    2008        Chennai  4/23/2008      5      1            1
# 8      9    2008      Hyderabad  4/24/2008      9      6            6
# 9     10    2008     Chandigarh  4/25/2008      8      1            1
# 10    11    2008      Bangalore  4/26/2008      3      6            6
# 11    12    2008        Chennai  4/26/2008      2      5            2
# 12    13    2008         Mumbai  4/27/2008      1      9            9
# 13    14    2008     Chandigarh  4/27/2008      4      8            4
# 14    15    2008      Bangalore  4/28/2008      5      3            5
# 15    16    2008        Kolkata  4/29/2008      2      1            2
# 16    17    2008          Delhi  4/30/2008      4      3            3
# 17    18    2008      Hyderabad   5/1/2008      9      8            8
# 18    19    2008         Jaipur   5/1/2008      6      2            6
# 19    20    2008        Chennai   5/2/2008      5      4            5
# 20    21    2008      Hyderabad  5/25/2008      9      3            9
# 21    22    2008     Chandigarh   5/3/2008      8      2            8
# 22    23    2008         Mumbai   5/4/2008      1      4            4
# 23    24    2008         Jaipur   5/4/2008      5      6            5
# 24    25    2008      Bangalore   5/5/2008      3      8            8
# 25    26    2008        Chennai   5/6/2008      5      9            9
# 26    27    2008         Mumbai   5/7/2008      6      1            1
# 27    28    2008          Delhi   5/8/2008      4      5            5
# 28    29    2008        Kolkata   5/8/2008      2      3            2
# 29    30    2008         Jaipur   5/9/2008      9      6            6
# ..   ...     ...            ...        ...    ...    ...          ...
# 547  548    2016         Rajkot   5/3/2016      7      4            4
# 548  549    2016        Kolkata   5/4/2016      2      8            8
# 549  550    2016          Delhi   5/5/2016      4     10           10
# 550  551    2016      Hyderabad   5/6/2016      7      9            9
# 551  552    2016      Bangalore   5/7/2016     10      3            3
# 552  553    2016     Chandigarh   5/7/2016      8      4            4
# 553  554    2016  Visakhapatnam   5/8/2016      9      1            1
# 554  555    2016        Kolkata   5/8/2016      2      7            7
# 555  556    2016     Chandigarh   5/9/2016      3      8            8
# 556  557    2016  Visakhapatnam  5/10/2016      9     10            9
# 557  558    2016      Bangalore  5/11/2016      3      1            1
# 558  559    2016      Hyderabad  5/12/2016      9      4            4
# 559  560    2016  Visakhapatnam  5/13/2016      1      8            1
# 560  561    2016      Bangalore  5/14/2016      3      7            7
# 561  562    2016        Kolkata  5/14/2016     10      2           10
# 562  563    2016     Chandigarh  5/15/2016      8      9            8
# 563  564    2016  Visakhapatnam  5/15/2016      1      4            4
# 564  565    2016        Kolkata  5/16/2016      2      3            3
# 565  566    2016  Visakhapatnam  5/17/2016      4     10           10
# 566  567    2016      Bangalore  5/18/2016      3      8            8
# 567  568    2016         Kanpur  5/19/2016      2      7            7
# 568  569    2016         Raipur  5/20/2016      9      4            4
# 569  570    2016  Visakhapatnam  5/21/2016      8     10            8
# 570  571    2016         Kanpur  5/21/2016      1      7            7
# 571  572    2016        Kolkata  5/22/2016      2      9            9
# 572  573    2016         Raipur  5/22/2016      4      3            3
# 573  574    2016      Bangalore  5/24/2016      7      3            3
# 574  575    2016          Delhi  5/25/2016      9      2            2
# 575  576    2016          Delhi  5/27/2016      7      9            9
# 576  577    2016      Bangalore  5/29/2016      9      3            9
#
#     toss_decision  result  dl_applied  winner  win_by_runs  win_by_wickets  \
# 0           field  normal           0     2.0          140               0
# 1             bat  normal           0     5.0           33               0
# 2             bat  normal           0     4.0            0               9
# 3             bat  normal           0     3.0            0               5
# 4             bat  normal           0     2.0            0               5
# 5             bat  normal           0     6.0            0               6
# 6             bat  normal           0     4.0            0               9
# 7           field  normal           0     5.0            6               0
# 8           field  normal           0     6.0            0               3
# 9           field  normal           0     8.0           66               0
# 10          field  normal           0     6.0            0               7
# 11            bat  normal           0     5.0            0               9
# 12          field  normal           0     9.0            0              10
# 13            bat  normal           0     8.0            0               4
# 14            bat  normal           0     5.0           13               0
# 15            bat  normal           0     1.0            0               7
# 16          field  normal           0     4.0           10               0
# 17          field  normal           0     8.0            0               7
# 18            bat  normal           0     6.0           45               0
# 19            bat  normal           0     4.0            0               8
# 20            bat  normal           0     3.0            0               5
# 21            bat  normal           0     8.0            9               0
# 22          field  normal           0     1.0           29               0
# 23            bat  normal           0     6.0            0               8
# 24          field  normal           0     8.0            0               6
# 25          field  normal           0     9.0            0               7
# 26          field  normal           0     1.0            0               7
# 27          field  normal           0     5.0            0               4
# 28            bat  normal           0     2.0            5               0
# 29          field  normal           0     6.0            0               8
# ..            ...     ...         ...     ...          ...             ...
# 547         field  normal           0     4.0            0               8
# 548         field  normal           0     2.0            7               0
# 549         field  normal           0    10.0            0               7
# 550         field  normal           0     9.0            0               5
# 551         field  normal           0     3.0            0               7
# 552         field  normal           0     8.0            9               0
# 553         field  normal           0     9.0           85               0
# 554         field  normal           0     7.0            0               5
# 555         field  normal           0     3.0            1               0
# 556           bat  normal           0     9.0            4               0
# 557         field  normal           0     1.0            0               6
# 558         field  normal           0     4.0            0               7
# 559           bat  normal           0     8.0            0               7
# 560         field  normal           0     3.0          144               0
# 561           bat  normal           1     2.0            0               8
# 562           bat  normal           0     9.0            0               7
# 563         field  normal           0     1.0           80               0
# 564         field  normal           0     3.0            0               9
# 565         field  normal           1    10.0           19               0
# 566         field  normal           1     3.0           82               0
# 567         field  normal           0     7.0            0               6
# 568         field  normal           0     4.0            0               6
# 569           bat  normal           0    10.0            0               4
# 570         field  normal           0     7.0            0               6
# 571         field  normal           0     2.0           22               0
# 572         field  normal           0     3.0            0               6
# 573         field  normal           0     3.0            0               4
# 574         field  normal           0     9.0           22               0
# 575         field  normal           0     9.0            0               4
# 576           bat  normal           0     9.0            8               0
#
#     player_of_match                                              venue
# 0       BB McCullum                              M Chinnaswamy Stadium
# 1        MEK Hussey         Punjab Cricket Association Stadium, Mohali
# 2       MF Maharoof                                   Feroz Shah Kotla
# 3        MV Boucher                                   Wankhede Stadium
# 4         DJ Hussey                                       Eden Gardens
# 5         SR Watson                             Sawai Mansingh Stadium
# 6          V Sehwag          Rajiv Gandhi International Stadium, Uppal
# 7         ML Hayden                    MA Chidambaram Stadium, Chepauk
# 8         YK Pathan          Rajiv Gandhi International Stadium, Uppal
# 9     KC Sangakkara         Punjab Cricket Association Stadium, Mohali
# 10        SR Watson                              M Chinnaswamy Stadium
# 11         JDP Oram                    MA Chidambaram Stadium, Chepauk
# 12     AC Gilchrist                         Dr DY Patil Sports Academy
# 13        SM Katich         Punjab Cricket Association Stadium, Mohali
# 14         MS Dhoni                              M Chinnaswamy Stadium
# 15    ST Jayasuriya                                       Eden Gardens
# 16       GD McGrath                                   Feroz Shah Kotla
# 17         SE Marsh          Rajiv Gandhi International Stadium, Uppal
# 18      SA Asnodkar                             Sawai Mansingh Stadium
# 19         V Sehwag                    MA Chidambaram Stadium, Chepauk
# 20    R Vinay Kumar          Rajiv Gandhi International Stadium, Uppal
# 21        IK Pathan         Punjab Cricket Association Stadium, Mohali
# 22       SM Pollock                         Dr DY Patil Sports Academy
# 23    Sohail Tanvir                             Sawai Mansingh Stadium
# 24      S Sreesanth                              M Chinnaswamy Stadium
# 25     AC Gilchrist                    MA Chidambaram Stadium, Chepauk
# 26          A Nehra                         Dr DY Patil Sports Academy
# 27         MS Dhoni                                   Feroz Shah Kotla
# 28       SC Ganguly                                       Eden Gardens
# 29        YK Pathan                             Sawai Mansingh Stadium
# ..              ...                                                ...
# 547         RR Pant             Saurashtra Cricket Association Stadium
# 548      AD Russell                                       Eden Gardens
# 549       AM Rahane                                   Feroz Shah Kotla
# 550         B Kumar          Rajiv Gandhi International Stadium, Uppal
# 551         V Kohli                              M Chinnaswamy Stadium
# 552      MP Stoinis  Punjab Cricket Association IS Bindra Stadium, ...
# 553         A Nehra  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 554         P Kumar                                       Eden Gardens
# 555       SR Watson  Punjab Cricket Association IS Bindra Stadium, ...
# 556         A Zampa  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 557       KH Pandya                              M Chinnaswamy Stadium
# 558       CH Morris          Rajiv Gandhi International Stadium, Uppal
# 559      MP Stoinis  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 560  AB de Villiers                              M Chinnaswamy Stadium
# 561       YK Pathan                                       Eden Gardens
# 562         HM Amla  Punjab Cricket Association IS Bindra Stadium, ...
# 563       KH Pandya  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 564         V Kohli                                       Eden Gardens
# 565        AB Dinda  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 566         V Kohli                              M Chinnaswamy Stadium
# 567        DR Smith                                         Green Park
# 568         KK Nair   Shaheed Veer Narayan Singh International Stadium
# 569        MS Dhoni  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 570        SK Raina                                         Green Park
# 571       YK Pathan                                       Eden Gardens
# 572         V Kohli   Shaheed Veer Narayan Singh International Stadium
# 573  AB de Villiers                              M Chinnaswamy Stadium
# 574    MC Henriques                                   Feroz Shah Kotla
# 575       DA Warner                                   Feroz Shah Kotla
# 576     BCJ Cutting                              M Chinnaswamy Stadium
#
# [577 rows x 15 columns]

# %%
X=Matches.drop('winner',axis=1)
y=Matches['winner']

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(
    Matches, test_size=0.2, random_state=42)

# %%
train_set_labels = train_set["winner"].copy()
train_set = train_set.drop("winner", axis=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn import model_selection

# %%
models = []
models.append(('LR', LogisticRegression()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVC', SVC()))
models.append(('LSVC', LinearSVC()))
models.append(('RFC', RandomForestClassifier()))
models.append(('DTR', DecisionTreeRegressor()))

# %%
seed = 7
results = []
names = []
X = train_set
Y = train_set_labels

# %%
for name, model in models:
    kfold = model_selection.KFold(
        n_splits=10, random_state=seed)
    cv_results = model_selection.cross_val_score(
        model, X, Y, cv=kfold, scoring='accuracy')
    results.append(cv_results)
    names.append(name)
    modelResult = "%s: %f (%f)" % (
        name, cv_results.mean(), cv_results.std())
    print(modelResult)
# Out:
# C:\Users\saide\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\saide\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:542: FutureWarning: From version 0.22, errors during fit will result in a cross validation score of NaN by default. Use error_score='raise' if you want an exception raised or error_score=np.nan to adopt the behavior from version 0.22.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-f7fb68831590> in <module>
#       3         n_splits=10, random_state=seed)
#       4     cv_results = model_selection.cross_val_score(
# ----> 5         model, X, Y, cv=kfold, scoring='accuracy')
#       6     results.append(cv_results)
#       7     names.append(name)
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     400                                 fit_params=fit_params,
#     401                                 pre_dispatch=pre_dispatch,
# --> 402                                 error_score=error_score)
#     403     return cv_results['test_score']
#     404
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     238             return_times=True, return_estimator=return_estimator,
#     239             error_score=error_score)
# --> 240         for train, test in cv.split(X, y, groups))
#     241
#     242     zipped_scores = list(zip(*scores))
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self, iterable)
#     915             # remaining jobs.
#     916             self._iterating = False
# --> 917             if self.dispatch_one_batch(iterator):
#     918                 self._iterating = self._original_iterator is not None
#     919
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     526             estimator.fit(X_train, **fit_params)
#     527         else:
# --> 528             estimator.fit(X_train, y_train, **fit_params)
#     529
#     530     except Exception as e:
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1283
#    1284         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1285                          accept_large_sparse=solver != 'liblinear')
#    1286         check_classification_targets(y)
#    1287         self.classes_ = np.unique(y)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# --> 527                 array = np.asarray(array, dtype=dtype, order=order)
#     528             except ComplexWarning:
#     529                 raise ValueError("Complex data not supported\n"
#
# ~\Anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'SJA Taufel'

# %%
Toss=Matches['toss_winner'].value_counts(sort=True)
Winner=Matches['winner'].value_counts(sort=True)

# %%
Toss
# Out:
# 1     74
# 9     73
# 2     69
# 5     66
# 8     64
# 4     64
# 6     63
# 3     61
# 10    27
# 11     8
# 7      8
# Name: toss_winner, dtype: int64

# %%
Winner
# Out:
# 1.0     80
# 5.0     79
# 3.0     70
# 2.0     68
# 9.0     63
# 8.0     63
# 6.0     63
# 4.0     56
# 10.0    17
# 7.0      9
# 11.0     6
# Name: winner, dtype: int64

# %%
MoM=Matches['player_of_match'].value_counts(sort=True)
MoM.head()
# Out:
# CH Gayle          17
# YK Pathan         16
# AB de Villiers    15
# DA Warner         14
# SK Raina          13
# Name: player_of_match, dtype: int64
