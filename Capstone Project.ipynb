# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Deliveries=pd.read_excel("C:\\Users\\saide\\Desktop\\Capstone Project\\ipldata\\deliveries.xlsx")
Matches=pd.read_excel("C:\\Users\\saide\\Desktop\\Capstone Project\\ipldata\\matches.xlsx")
International_Stats_T20=pd.read_csv("C:\\Users\\saide\\Desktop\\Capstone Project\\ipldata\\Men T20I Player Innings Stats - 21st Century.csv")
International_Stats_Batting=pd.read_csv("C:\\Users\\saide\\Desktop\\Capstone Project\\ipldata\\Men T20I Team Batting Stats.csv")
International_Stats_Bowling=pd.read_csv("C:\\Users\\saide\\Desktop\\Capstone Project\\ipldata\\Men T20I Team Bowling Stats.csv")

# %%
Deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over   ...    bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0   ...           0
# 1     2  DA Warner    S Dhawan  TS Mills              0   ...           0
# 2     3  DA Warner    S Dhawan  TS Mills              0   ...           0
# 3     4  DA Warner    S Dhawan  TS Mills              0   ...           0
# 4     5  DA Warner    S Dhawan  TS Mills              0   ...           0
#
# ...

# %%
Matches.head()
# Out:
#    id  season       city                 date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05 00:00:00          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06 00:00:00               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07 00:00:00                Gujarat Lions
# 3   4    2017     Indore  2017-04-08 00:00:00       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08 00:00:00  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4               Delhi Capitals  Royal Challengers Bangalore           bat
#
# ...

# %%
International_Stats_T20.head()
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0       AD Hales                116*                     116
# 1       DJ Malan                103*                     103
# 2      LJ Wright                 99*                      99
# 3       AD Hales                  99                      99
# 4       AD Hales                  94                      94
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                     97                  1.0                   1.0
# 1                     79                  1.0                   1.0
# 2                     83                  1.0                   1.0
# 3                     84                  1.0                   0.0
# 4                     80                  1.0                   0.0
#
#   Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                  64                     11                      6
# ...

# %%
International_Stats_Batting.head()
# Out:
#         Country  Team Matches Played  Matches Won  Matches Lost  Matches Tied  \
# 0       England                  117           58            53             2
# 1     Australia                  124           66            53             2
# 2  South Africa                  120           70            48             1
# 3   West Indies                  122           52            62             3
# 4   New Zealand                  131           61            59             8
#
#    Matches With No Result  Win/Loss Ratio  Avg Runs Per Wicket Batting  \
# 0                       4           1.094                        24.81
# 1                       3           1.245                        26.38
# 2                       1           1.458                        27.33
# 3                       5           0.838                        22.31
# 4                       3           1.033                        23.42
#
#    Avg Runs Per Six Balls Batting  Number Of Team Innings Batting  \
# ...

# %%
International_Stats_Bowling.head()
# Out:
#         Country  Avg Runs Per Wicket Bowling  Avg Runs Per Six Balls Bowling  \
# 0       England                        24.40                            8.24
# 1     Australia                        22.53                            7.81
# 2  South Africa                        21.35                            7.88
# 3   West Indies                        24.21                            7.96
# 4   New Zealand                        23.54                            8.05
#
#    Number Of Team Innings Bowling  Highest Team Score Bowling  \
# 0                             116                         248
# 1                             123                         243
# 2                             120                         236
# 3                             122                         244
# 4                             130                         245
#
#    Lowest Completed Score Bowling
# 0                              45
# 1                              74
# ...

# %%
Deliveries.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
Matches.describe()
# Out:
#                  id       season  win_by_runs  win_by_wickets
# count    756.000000   756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    13.283069        3.350529
# std     3464.478148     3.366895    23.471144        3.387963
# min        1.000000  2008.000000     0.000000        0.000000
# 25%      189.750000  2011.000000     0.000000        0.000000
# 50%      378.500000  2013.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    19.000000        6.000000
# max    11415.000000  2019.000000   146.000000       10.000000

# %%
International_Stats_T20.describe()
# Out:
#        Innings Batted Flag  Innings Not Out Flag          50's         100's  \
# count         17327.000000          17327.000000  17327.000000  17327.000000
# mean              0.721071              0.157154      0.053558      0.002366
# std               0.448485              0.363956      0.225150      0.048588
# min               0.000000              0.000000      0.000000      0.000000
# 25%               0.000000              0.000000      0.000000      0.000000
# 50%               1.000000              0.000000      0.000000      0.000000
# 75%               1.000000              0.000000      0.000000      0.000000
# max               1.000000              1.000000      1.000000      1.000000
#
#        Innings Bowled Flag     4 Wickets     5 Wickets  10 Wickets
# count         17327.000000  17327.000000  17327.000000     17327.0
# mean              0.531194      0.998038      0.001962         0.0
# std               0.499040      0.044255      0.044255         0.0
# ...

# %%
International_Stats_Batting.describe()
# Out:
#        Team Matches Played  Matches Won  Matches Lost  Matches Tied  \
# count            17.000000    17.000000     17.000000     17.000000
# mean             92.647059    46.000000     42.647059      1.705882
# std              41.397375    25.455844     18.459216      1.961017
# min              15.000000     4.000000      4.000000      0.000000
# 25%              74.000000    29.000000     32.000000      0.000000
# 50%              95.000000    52.000000     48.000000      1.000000
# 75%             124.000000    61.000000     55.000000      2.000000
# max             151.000000    92.000000     63.000000      8.000000
#
#        Matches With No Result  Win/Loss Ratio  Avg Runs Per Wicket Batting  \
# count               17.000000       17.000000                    17.000000
# mean                 2.294118        1.186176                    22.616471
# std                  1.992633        0.683434                     3.923253
# ...

# %%
International_Stats_Bowling.describe()
# Out:
#        Avg Runs Per Wicket Bowling  Avg Runs Per Six Balls Bowling  \
# count                    17.000000                       17.000000
# mean                     22.385294                        7.626471
# std                       3.013178                        0.555697
# min                      14.220000                        5.930000
# 25%                      21.040000                        7.410000
# 50%                      22.530000                        7.790000
# 75%                      24.210000                        7.960000
# max                      26.960000                        8.240000
#
#        Number Of Team Innings Bowling  Highest Team Score Bowling  \
# count                       17.000000                   17.000000
# mean                        91.588235                  236.294118
# std                         41.287194                   21.976592
# min                         15.000000                  197.000000
# ...

# %%
CorRelation1=Deliveries.corr()
CorRelation1
# Out:
#                match_id    inning      over      ball  is_super_over  \
# match_id       1.000000  0.003958  0.008268 -0.001349      -0.009150
# inning         0.003958  1.000000 -0.050076 -0.003943       0.084154
# over           0.008268 -0.050076  1.000000 -0.007424      -0.034329
# ball          -0.001349 -0.003943 -0.007424  1.000000      -0.001143
# is_super_over -0.009150  0.084154 -0.034329 -0.001143       1.000000
# wide_runs     -0.007549  0.001201 -0.010003 -0.004665      -0.001019
# bye_runs       0.000905 -0.000757  0.012111  0.006602       0.001353
# legbye_runs   -0.012429 -0.001996 -0.004764 -0.002727       0.001735
# noball_runs   -0.004623 -0.000904  0.016984  0.000567       0.013640
# penalty_runs  -0.001475  0.003442 -0.000979  0.000711      -0.000071
# batsman_runs   0.033510 -0.005362  0.086701  0.007950       0.010125
# extra_runs    -0.013323 -0.000531 -0.002479 -0.002576       0.003504
# total_runs     0.030727 -0.005485  0.086326  0.007414       0.010891
#
# ...

# %%
CorRelationMatrix1 = Deliveries.corr() 
  
Matrix1 = sns.clustermap(CorRelationMatrix1, cmap ="YlGnBu", linewidths = 0.1); 
plt.setp(Matrix1.ax_heatmap.yaxis.get_majorticklabels(), rotation = 0) 
  
Matrix1

# %%
CorRelation2=Matches.corr()
CorRelation2
# Out:
#                       id    season  win_by_runs  win_by_wickets
# id              1.000000  0.668304    -0.039403       -0.012239
# season          0.668304  1.000000    -0.037529       -0.009379
# win_by_runs    -0.039403 -0.037529     1.000000       -0.560420
# win_by_wickets -0.012239 -0.009379    -0.560420        1.000000

# %%
CorRelationMatrix2 = Matches.corr() 
  
Matrix2 = sns.clustermap(CorRelationMatrix2, cmap ="YlGnBu", linewidths = 0.1); 
plt.setp(Matrix2.ax_heatmap.yaxis.get_majorticklabels(), rotation = 0) 
  
Matrix2

# %%
CorRelation3=International_Stats_T20.corr()
CorRelation3
# Out:
#                       Innings Batted Flag  Innings Not Out Flag      50's  \
# Innings Batted Flag              1.000000              0.268563  0.147953
# Innings Not Out Flag             0.268563              1.000000  0.098721
# 50's                             0.147953              0.098721  1.000000
# 100's                            0.030290              0.063829 -0.011585
# Innings Bowled Flag                   NaN                   NaN       NaN
# 4 Wickets                             NaN                   NaN       NaN
# 5 Wickets                             NaN                   NaN       NaN
# 10 Wickets                            NaN                   NaN       NaN
#
#                          100's  Innings Bowled Flag  4 Wickets  5 Wickets  \
# Innings Batted Flag   0.030290                  NaN        NaN        NaN
# Innings Not Out Flag  0.063829                  NaN        NaN        NaN
# 50's                 -0.011585                  NaN        NaN        NaN
# ...

# %%
CorRelationMatrix3 = International_Stats_T20.corr() 

Matrix3,ax = plt.subplots(figsize =(9, 8)) 
sns.heatmap(CorRelationMatrix3, ax = ax, cmap ="YlGnBu", linewidths = 0.1)

# %%
CorRelation4=International_Stats_Batting.corr()
CorRelation4
# Out:
#                                 Team Matches Played  Matches Won  \
# Team Matches Played                        1.000000     0.920237
# Matches Won                                0.920237     1.000000
# Matches Lost                               0.859427     0.596676
# Matches Tied                               0.630717     0.520840
# Matches With No Result                     0.436997     0.303110
# Win/Loss Ratio                            -0.002505     0.297451
# Avg Runs Per Wicket Batting                0.597787     0.724719
# Avg Runs Per Six Balls Batting             0.614396     0.643945
# Number Of Team Innings Batting             0.999430     0.921324
# Highest Team Score Batting                 0.492074     0.546043
# Lowest Completed Score Batting            -0.056014     0.025708
#
#                                 Matches Lost  Matches Tied  \
# Team Matches Played                 0.859427      0.630717
# Matches Won                         0.596676      0.520840
# ...

# %%
CorRelationMatrix4 = International_Stats_Batting.corr() 
  
Matrix4 = sns.clustermap(CorRelationMatrix4, cmap ="YlGnBu", linewidths = 0.1); 
plt.setp(Matrix4.ax_heatmap.yaxis.get_majorticklabels(), rotation = 0) 
  
Matrix4

# %%
CorRelation5=International_Stats_Bowling.corr()
CorRelation5
# Out:
#                                 Avg Runs Per Wicket Bowling  \
# Avg Runs Per Wicket Bowling                        1.000000
# Avg Runs Per Six Balls Bowling                     0.866778
# Number Of Team Innings Bowling                     0.281100
# Highest Team Score Bowling                         0.123759
# Lowest Completed Score Bowling                     0.345552
#
#                                 Avg Runs Per Six Balls Bowling  \
# Avg Runs Per Wicket Bowling                           0.866778
# Avg Runs Per Six Balls Bowling                        1.000000
# Number Of Team Innings Bowling                        0.591503
# Highest Team Score Bowling                            0.347076
# Lowest Completed Score Bowling                        0.102075
#
#                                 Number Of Team Innings Bowling  \
# Avg Runs Per Wicket Bowling                           0.281100
# Avg Runs Per Six Balls Bowling                        0.591503
# ...

# %%
CorRelationMatrix5 = International_Stats_Bowling.corr() 
  
Matrix5 = sns.clustermap(CorRelationMatrix5, cmap ="YlGnBu", linewidths = 0.1); 
plt.setp(Matrix5.ax_heatmap.yaxis.get_majorticklabels(), rotation = 0) 
  
Matrix5

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(
    Deliveries, test_size=0.2, random_state=42)

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(
    Matches, test_size=0.2, random_state=42)

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(
    International_Stats_T20, test_size=0.2, random_state=42)

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(
    International_Stats_Batting, test_size=0.2, random_state=42)

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(
    International_Stats_Bowling, test_size=0.2, random_state=42)

# %%
train_set_labels = train_set["Avg Runs Per Wicket Bowling"].copy()
train_set = train_set.drop("Avg Runs Per Wicket Bowling", axis=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn import model_selection

# %%
models = []
models.append(('LR', LogisticRegression()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVC', SVC()))
models.append(('LSVC', LinearSVC()))
models.append(('RFC', RandomForestClassifier()))
models.append(('DTR', DecisionTreeRegressor()))

# %%
seed = 7
results = []
names = []
X = train_set
Y = train_set_labels

# %%
for name, model in models:
    kfold = model_selection.KFold(
        n_splits=5, random_state=seed)
    cv_results = model_selection.cross_val_score(
         model,X, Y, cv=kfold, scoring='accuracy')
    results.append(cv_results)
    names.append(name)
    modelResult = "%s: %f (%f)" % (
        name, cv_results.mean(), cv_results.std())
    print(modelResult)
# Out:
# C:\Users\saide\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\saide\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:542: FutureWarning: From version 0.22, errors during fit will result in a cross validation score of NaN by default. Use error_score='raise' if you want an exception raised or error_score=np.nan to adopt the behavior from version 0.22.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-896660e60dc9> in <module>
#       3         n_splits=5, random_state=seed)
#       4     cv_results = model_selection.cross_val_score(
# ----> 5          model,X, Y, cv=kfold, scoring='accuracy')
#       6     results.append(cv_results)
#       7     names.append(name)
#
# ...
